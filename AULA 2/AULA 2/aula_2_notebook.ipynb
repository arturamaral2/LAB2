# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
nome = 'dados.txt'
df = pd.read_csv(nome, header = None)

# %%
df = df.rename(columns = {1:'temperatura',0:'potencia'})

# %%
sns.lineplot(data = df, x='potencia', y = 'temperatura')
# Out:
# <AxesSubplot:xlabel='potencia', ylabel='temperatura'>

# %%
sns.lineplot(data = df, x = df.index, y = 'temperatura')
# Out:
# <AxesSubplot:ylabel='temperatura'>

# %%
sns.lineplot(data = df, x = df.index, y = 'potencia')
# Out:
# <AxesSubplot:ylabel='potencia'>

# %%
x =np.linspace(0,100,1000).reshape((-1,1))

# %%
slope = model.coef_[0]

# %%
slope
# Out:
# -0.11643061333800166

# %%
y = x*(-slope) + t_ambiente

# %%
plt.plot(x,y)

# %%
df['variacao'] = df['temperatura']/df['potencia']

# %%
x = df['potencia']
y = df['temperatura']

x= np.array(x).reshape((-1,1))
y= np.array(y)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
print('intercept :',model.intercept_)
# Out:
# intercept 47231.77825361759

# %%
print('slop :',model.coef_)
# Out:
# slop : [-0.11643061]

# %%
t1 = 29
tmax = 34.5
tf = 28.5 
t_ambiente = 25,3

# %%
sns.lineplot(data = df, y='potencia', x = 'temperatura')
# Out:
# <AxesSubplot:xlabel='temperatura', ylabel='potencia'>
